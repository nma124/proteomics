# %%
import pandas as pd
import pathlib
import numpy as np

# %% [markdown]
# ## Load Data

# %%
raw_data_dir = pathlib.Path("../../data/raw/soroush_2")

trans_res_path = raw_data_dir.joinpath('2023.09.06 BSA_OVA_quant_super_akin.csv')
trans_res_df_raw = pd.read_csv(trans_res_path)
trans_res_df_raw.columns = trans_res_df_raw.columns.map(str.lower)
trans_res_df_raw.head()
# Out:
#             peptide               protein  \
# 0  GGLEPINFQTAADQAR  sp|P01012|OVAL_CHICK
# 1  GGLEPINFQTAADQAR  sp|P01012|OVAL_CHICK
# 2  GGLEPINFQTAADQAR  sp|P01012|OVAL_CHICK
# 3  GGLEPINFQTAADQAR  sp|P01012|OVAL_CHICK
# 4  GGLEPINFQTAADQAR  sp|P01012|OVAL_CHICK
#
#                                    replicate  precursor mz  precursor charge  \
# 0   Soroush_SDC_W1730_Sup_D0_column12_2uL_20     844.42355                 2
# 1   Soroush_SDC_W1730_Sup_D0_column12_2uL_80     844.42355                 2
# 2  Soroush_SDC_W1730_Sup_D1_column12_2uL_141     844.42355                 2
# 3  Soroush_SDC_W1730_Sup_D1_column12_2uL_159     844.42355                 2
# 4   Soroush_SDC_W1730_Sup_D2_column12_2uL_32     844.42355                 2
#
#    product mz  product charge fragment ion  retention time          area  \
# 0   844.42355               2    precursor           47.00  7.575379e+09
# 1   844.42355               2    precursor           45.96  9.467220e+09
# 2   844.42355               2    precursor           46.89  5.926985e+07
# 3   844.42355               2    precursor           45.72  3.679658e+09
# 4   844.42355               2    precursor           46.89  3.454373e+09
#
#    background
# 0   133355208
# 1       98842
# 2           0
# 3    20224484
# 4    30604174

# %%
trans_res_df_raw.peptide.unique()
# Out:
# array(['GGLEPINFQTAADQAR', 'AEFVEVTK', 'YICDNQDTISSK'], dtype=object)

# %% [markdown]
# ## Compute Area ratio

# %%
# def grp_area_ratio(grouped_df:pd.DataFrame):
    
#     """compute the ratio of areas with higer precursor mz value as numerator."""

#     df = grouped_df[['precursor mz', 'area']].copy()
#     df = df.sort_values(by='precursor mz', ascending=True)
#     area_ratio = df['area'].iloc[1] / df['area'].iloc[0]

#     return area_ratio

def grp_area_ratio_n_area_cols(grouped_df:pd.DataFrame):
    
    """compute the ratio of areas with higer precursor mz value as numerator."""

    df = grouped_df[['precursor mz', 'area']].copy()
    df = df.sort_values(by='precursor mz', ascending=True)
    area_ratio = df['area'].iloc[1] / df['area'].iloc[0]
    area_min, area_max  =  df['area'].iloc[0], df['area'].iloc[1]

    col_vals = {'area_ratio': area_ratio, 'area_min':area_min, 'area_max':area_max}

    return pd.Series(col_vals)

cols_to_group_by = ['peptide', 'protein', 'replicate', 'product charge', 'fragment ion']
# df_area_ratio = trans_res_df_raw.groupby(cols_to_group_by).apply(grp_area_ratio).reset_index(name='area_ratio')
df_area_ratio = trans_res_df_raw.groupby(cols_to_group_by).apply(grp_area_ratio_n_area_cols).reset_index()


# df_area_ratio = df_area_ratio[df_area_ratio['fragment ion'] == 'precursor']  # select only precursor
print(df_area_ratio.shape)
df_area_ratio.head()
# Out:
# c:\Users\Aroge\anaconda3\envs\genomic\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in double_scalars
# c:\Users\Aroge\anaconda3\envs\genomic\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars
# (1080, 8)
#     peptide               protein                                 replicate  \
# 0  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 1  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 2  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 3  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 4  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
#
#    product charge fragment ion  area_ratio      area_min   area_max
# 0               1           b2    0.000344  3.157382e+09  1085662.0
# 1               1           y2    0.000128  4.009150e+08    51280.0
# 2               1           y4    0.000017  6.640748e+08    11599.0
# 3               1           y5    0.000003  8.254646e+08     2376.0
# 4               1           y6    0.000171  2.778528e+09   475204.0

# %%
np.isinf(df_area_ratio.area_ratio).sum()
# Out:
# 15

# %% [markdown]
# ## Get peptide Dilution Conc.

# %%
# df_peptide_dilution_conc = pd.read_csv(raw_data_dir.joinpath('Soroush_2023_09_06_peptide_dilution_conc.csv'))
# # df_peptide_dilution_conc.columns


# df_peptide_dilution_conc.head()
# raw_dilution_col_names = df_peptide_dilution_conc.columns[1:]


# df_peptide_dilution_conc = df_peptide_dilution_conc.melt(id_vars='Peptides', value_vars=raw_dilution_col_names, 
#                                                         var_name='dilution', value_name='heavy_conc')
# df_peptide_dilution_conc['dilution'] = df_peptide_dilution_conc['dilution'].apply(lambda x: x[:2])
# df_peptide_dilution_conc['peptide_dilution_name'] = df_peptide_dilution_conc['Peptides'] + '_' + \
# df_peptide_dilution_conc['dilution'] 
# df_peptide_dilution_conc.head()

# %%
def get_peptide_dilution_comb(row):
    """function to create a new column from peptide and dilution name."""
    peptide = row['peptide']
    replicate  = row['replicate']
    dilution = get_dilution_from_replicate(rep_string=replicate)

    return peptide + '_' + dilution

df_peptide_dilution_conc = pd.read_csv(raw_data_dir.joinpath('Soroush_2023_09_06_peptide_dilution_conc.csv'))
raw_dilution_col_names = df_peptide_dilution_conc.columns[1:]

df_peptide_dilution_conc = df_peptide_dilution_conc.melt(id_vars='Peptides', value_vars=raw_dilution_col_names, 
                                                        var_name='dilution', value_name='heavy_conc')
df_peptide_dilution_conc['dilution'] = df_peptide_dilution_conc['dilution'].apply(lambda x: x[:2])
peptide_dilution_name_col = 'peptide_dilution_name'
df_peptide_dilution_conc[peptide_dilution_name_col] = df_peptide_dilution_conc['Peptides'] + '_' + \
                                                    df_peptide_dilution_conc['dilution'] 
df_peptide_dilution_conc.head()
# Out:
#            Peptides dilution  heavy_conc peptide_dilution_name
# 0  GGLEPINFQTAADQAR       D1    0.736000   GGLEPINFQTAADQAR_D1
# 1          AEFVEVTK       D1    0.403667           AEFVEVTK_D1
# 2      YICDNQDTISSK       D1    1.257333       YICDNQDTISSK_D1
# 3  GGLEPINFQTAADQAR       D2    0.184000   GGLEPINFQTAADQAR_D2
# 4          AEFVEVTK       D2    0.100917           AEFVEVTK_D2

# %% [markdown]
# ### Merge data

# %%
def get_dilution_from_replicate(rep_string:str):
    """Get the dilution symbol from the replicate name."""

    str_to_check = rep_string.split('_')[4]
    if str_to_check.startswith('col'):
        dilution = 'D0'
    else:
        dilution = str_to_check

    return dilution

df_area_ratio[peptide_dilution_name_col] = df_area_ratio.apply(get_peptide_dilution_comb, axis=1)



df_area_ratio_conc = pd.merge(df_area_ratio, right=df_peptide_dilution_conc, how='left', 
                              on=peptide_dilution_name_col, suffixes=('', '_y'))
df_area_ratio_conc.drop(df_area_ratio_conc.filter(regex='_y$').columns, axis=1, inplace=True)
df_area_ratio_conc = df_area_ratio_conc.dropna(axis=0) # drop nan
# drop inf
df_area_ratio_conc.replace([np.inf, -np.inf], np.nan, inplace=True)
# df_area_ratio_conc.dropna(subset=["area_ratio"], how="all", inplace=True)

# def get_rep_plot_cat(rep_val:str):
#     """Get the plot category (C18_SDS, C18_SDC, etc..)."""

#     select_elements = rep_val.split('_')[1:3]

#     cat = '_'.join(select_elements)
#     return cat

# TODO: - reverse x and y in plots: ratio:y, conc: x
#- TODO: further break replicate into 2 groups as shown in the excel, the greens are one group and the white is another.
def get_rep_plot_cat(row):
    """Get the plot category (C18_SDS, C18_SDC, etc..)."""

    replicate = row['replicate']
    peptide = row['peptide']
    fragment_ion = row['fragment ion']

    rep_elements = replicate.split('_')[0:3]

    cat_name = [peptide] + [fragment_ion] + rep_elements
    cat_name = '_'.join(cat_name)
    return cat_name


# create plot categories
df_area_ratio_conc['plot_cat'] = df_area_ratio_conc.apply(get_rep_plot_cat, axis=1)

# %%
df_area_ratio_conc['plot_cat'].value_counts()
# Out:
# GGLEPINFQTAADQAR_y12_Soroush_SDC_W1730    20
# AEFVEVTK_y6_Soroush_SDC_W1730             20
# YICDNQDTISSK_y10_Soroush_SDC_WR           20
# YICDNQDTISSK_y10_Soroush_SDC_WW           20
# GGLEPINFQTAADQAR_y12_Soroush_SDC_WW       20
#                                           ..
# GGLEPINFQTAADQAR_y10_Soroush_SDC_W1730    10
# AEFVEVTK_y5_Soroush_SDC_W1730             10
# YICDNQDTISSK_y3_Soroush_SDC_W42           10
# YICDNQDTISSK_b3_Soroush_SDC_WW             9
# YICDNQDTISSK_b3_Soroush_SDC_W42            9
# Name: plot_cat, Length: 96, dtype: int64

# %%
temp_df = df_area_ratio_conc.copy()
temp_df['rep_partial'] = temp_df['replicate'].apply(lambda x: '_'.join(x.split('_')[:-1]))
temp_df['rep_partial_last'] = temp_df['replicate'].apply(lambda x: x.split('_')[-1])

grp_df = temp_df.groupby(['plot_cat', 'rep_partial'])
temp_df.head()
# Out:
#     peptide               protein                                 replicate  \
# 0  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 1  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 2  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 3  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 4  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
#
#    product charge fragment ion  area_ratio      area_min   area_max  \
# 0               1           b2    0.000344  3.157382e+09  1085662.0
# 1               1           y2    0.000128  4.009150e+08    51280.0
# 2               1           y4    0.000017  6.640748e+08    11599.0
# 3               1           y5    0.000003  8.254646e+08     2376.0
# 4               1           y6    0.000171  2.778528e+09   475204.0
#
#   peptide_dilution_name  Peptides dilution  heavy_conc  \
# 0           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 1           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 2           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 3           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 4           AEFVEVTK_D0  AEFVEVTK       D0         0.0
#
#                         plot_cat                            rep_partial  \
# 0  AEFVEVTK_b2_Soroush_SDC_W1730  Soroush_SDC_W1730_Sup_D0_column12_2uL
# 1  AEFVEVTK_y2_Soroush_SDC_W1730  Soroush_SDC_W1730_Sup_D0_column12_2uL
# 2  AEFVEVTK_y4_Soroush_SDC_W1730  Soroush_SDC_W1730_Sup_D0_column12_2uL
# 3  AEFVEVTK_y5_Soroush_SDC_W1730  Soroush_SDC_W1730_Sup_D0_column12_2uL
# 4  AEFVEVTK_y6_Soroush_SDC_W1730  Soroush_SDC_W1730_Sup_D0_column12_2uL
#
#   rep_partial_last
# 0               20
# 1               20
# 2               20
# 3               20
# 4               20

# %%
grp_df.groups.items()
# Out:
# dict_items([(('AEFVEVTK_b2_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D0_column12_2uL'), Int64Index([0, 9], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D1_column12_2uL'), Int64Index([18, 27], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D2_column12_2uL'), Int64Index([36, 45], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D3_column12_2uL'), Int64Index([54, 63], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D4_column12_2uL'), Int64Index([72, 81], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D0_column12_2uL'), Int64Index([90, 99], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D1_column12_2uL'), Int64Index([108, 117], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D2_column12_2uL'), Int64Index([126, 135], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D3_column12_2uL'), Int64Index([144, 153], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D4_column12_2uL'), Int64Index([162, 171], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D0_column12_2uL'), Int64Index([180, 189], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D1_column12_2uL'), Int64Index([198, 207], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D2_column12_2uL'), Int64Index([216, 225], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D3_column12_2uL'), Int64Index([234, 243], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D4_column12_2uL'), Int64Index([252, 261], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WW', 'Soroush_SDC_WW_Sup_D0_column12_2uL'), Int64Index([270, 279], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WW', 'Soroush_SDC_WW_Sup_D1_column12_2uL'), Int64Index([288, 297], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WW', 'Soroush_SDC_WW_Sup_D2_column12_2uL'), Int64Index([306, 315], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WW', 'Soroush_SDC_WW_Sup_D3_column12_2uL'), Int64Index([324, 333], dtype='int64')), (('AEFVEVTK_b2_Soroush_SDC_WW', 'Soroush_SDC_WW_Sup_D4_column12_2uL'), Int64Index([342, 351], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D0_column12_2uL'), Int64Index([6, 15], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D1_column12_2uL'), Int64Index([24, 33], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D2_column12_2uL'), Int64Index([42, 51], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D3_column12_2uL'), Int64Index([60, 69], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D4_column12_2uL'), Int64Index([78, 87], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D0_column12_2uL'), Int64Index([96, 105], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D1_column12_2uL'), Int64Index([114, 123], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D2_column12_2uL'), Int64Index([132, 141], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D3_column12_2uL'), Int64Index([150, 159], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_W42', 'Soroush_SDC_W42_Sup_D4_column12_2uL'), Int64Index([168, 177], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D0_column12_2uL'), Int64Index([186, 195], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D1_column12_2uL'), Int64Index([204, 213], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D2_column12_2uL'), Int64Index([222, 231], dtype='int64')), (('AEFVEVTK_precursor [M+1]_Soroush_SDC_WR', 'Soroush_SDC_WR_Sup_D3_column12_2uL'), Int64Index([240, 2 ...

# %%
grp_df.get_group(('AEFVEVTK_b2_Soroush_SDC_W1730', 'Soroush_SDC_W1730_Sup_D0_column12_2uL'))
# Out:
#     peptide               protein                                 replicate  \
# 0  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 9  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_80
#
#    product charge fragment ion  area_ratio      area_min   area_max  \
# 0               1           b2    0.000344  3.157382e+09  1085662.0
# 9               1           b2    0.000399  3.204261e+09  1279067.0
#
#   peptide_dilution_name  Peptides dilution  heavy_conc  \
# 0           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 9           AEFVEVTK_D0  AEFVEVTK       D0         0.0
#
#                         plot_cat                            rep_partial  \
# 0  AEFVEVTK_b2_Soroush_SDC_W1730  Soroush_SDC_W1730_Sup_D0_column12_2uL
# 9  AEFVEVTK_b2_Soroush_SDC_W1730  Soroush_SDC_W1730_Sup_D0_column12_2uL
#
#   rep_partial_last
# 0               20
# 9               80

# %%
def get_order(grouped_df):

    order_vals = []
    for rep_value in grouped_df['replicate'].values:
        rep_partial = rep_value.split('_')[:-1]
        rep_last_val = int(rep_value.split('_')[-1])

        for rep_value_2 in grouped_df['replicate'].values:
            rep_partial_2 = rep_value_2.split('_')[:-1]
            rep_last_val_2 = int(rep_value_2.split('_')[-1])

            found_match = False
            if rep_value != rep_value_2 and rep_partial == rep_partial_2:
                found_match = True
                if rep_last_val < rep_last_val_2:
                    order_val = 'low'
                elif rep_last_val > rep_last_val_2:
                    order_val = 'high'
                break
                
        if found_match:
            order_vals.append(order_val)
        else:
            order_vals.append('no match')

        
    
    grouped_df['order'] = order_vals
    return grouped_df
order = df_area_ratio_conc.groupby('plot_cat').apply(get_order)['order']
df_area_ratio_conc['plot_cat'] = df_area_ratio_conc['plot_cat'] + '_' + order
df_area_ratio_conc.head()
# print(df_area_ratio_conc.isna().sum())
# df_area_ratio_conc = df_area_ratio_conc[df_area_ratio_conc['area_ratio'].notna()]
# print(df_area_ratio_conc.isna().sum())
df_area_ratio_conc.head()
# Out:
#     peptide               protein                                 replicate  \
# 0  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 1  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 2  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 3  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 4  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
#
#    product charge fragment ion  area_ratio      area_min   area_max  \
# 0               1           b2    0.000344  3.157382e+09  1085662.0
# 1               1           y2    0.000128  4.009150e+08    51280.0
# 2               1           y4    0.000017  6.640748e+08    11599.0
# 3               1           y5    0.000003  8.254646e+08     2376.0
# 4               1           y6    0.000171  2.778528e+09   475204.0
#
#   peptide_dilution_name  Peptides dilution  heavy_conc  \
# 0           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 1           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 2           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 3           AEFVEVTK_D0  AEFVEVTK       D0         0.0
# 4           AEFVEVTK_D0  AEFVEVTK       D0         0.0
#
#                             plot_cat
# 0  AEFVEVTK_b2_Soroush_SDC_W1730_low
# 1  AEFVEVTK_y2_Soroush_SDC_W1730_low
# 2  AEFVEVTK_y4_Soroush_SDC_W1730_low
# 3  AEFVEVTK_y5_Soroush_SDC_W1730_low
# 4  AEFVEVTK_y6_Soroush_SDC_W1730_low

# %%
df_area_ratio_conc[df_area_ratio_conc.plot_cat.apply(lambda x: x.split('_')[-1] == 'no match')]
# Out:
#            peptide               protein  \
# 847   YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1054  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
#
#                                    replicate  product charge fragment ion  \
# 847   Soroush_SDC_W42_Sup_D2_column12_2uL_33               1           b3
# 1054   Soroush_SDC_WW_Sup_D3_column12_2uL_95               1           b3
#
#       area_ratio   area_min     area_max peptide_dilution_name      Peptides  \
# 847    47.961354  8337061.0  399856736.0       YICDNQDTISSK_D2  YICDNQDTISSK
# 1054    7.019977  7057353.0   49542456.0       YICDNQDTISSK_D3  YICDNQDTISSK
#
#      dilution  heavy_conc                                  plot_cat
# 847        D2    0.314333  YICDNQDTISSK_b3_Soroush_SDC_W42_no match
# 1054       D3    0.078583   YICDNQDTISSK_b3_Soroush_SDC_WW_no match

# %%
df_area_ratio_conc['plot_cat'].value_counts()
# Out:
# YICDNQDTISSK_y10_Soroush_SDC_WW_low         10
# GGLEPINFQTAADQAR_y12_Soroush_SDC_WR_low     10
# GGLEPINFQTAADQAR_y12_Soroush_SDC_WR_high    10
# GGLEPINFQTAADQAR_y12_Soroush_SDC_WW_high    10
# GGLEPINFQTAADQAR_y12_Soroush_SDC_WW_low     10
#                                             ..
# YICDNQDTISSK_b3_Soroush_SDC_WW_low           4
# YICDNQDTISSK_b3_Soroush_SDC_W42_low          4
# YICDNQDTISSK_b3_Soroush_SDC_WW_high          4
# YICDNQDTISSK_b3_Soroush_SDC_W42_no match     1
# YICDNQDTISSK_b3_Soroush_SDC_WW_no match      1
# Name: plot_cat, Length: 194, dtype: int64

# %%
df_area_ratio_conc['plot_cat'][:20]
# Out:
# 0                   AEFVEVTK_b2_Soroush_SDC_W1730_low
# 1                   AEFVEVTK_y2_Soroush_SDC_W1730_low
# 2                   AEFVEVTK_y4_Soroush_SDC_W1730_low
# 3                   AEFVEVTK_y5_Soroush_SDC_W1730_low
# 4                   AEFVEVTK_y6_Soroush_SDC_W1730_low
# 5            AEFVEVTK_precursor_Soroush_SDC_W1730_low
# 6      AEFVEVTK_precursor [M+1]_Soroush_SDC_W1730_low
# 7      AEFVEVTK_precursor [M+2]_Soroush_SDC_W1730_low
# 8                   AEFVEVTK_y6_Soroush_SDC_W1730_low
# 9                  AEFVEVTK_b2_Soroush_SDC_W1730_high
# 10                 AEFVEVTK_y2_Soroush_SDC_W1730_high
# 11                 AEFVEVTK_y4_Soroush_SDC_W1730_high
# 12                 AEFVEVTK_y5_Soroush_SDC_W1730_high
# 13                 AEFVEVTK_y6_Soroush_SDC_W1730_high
# 14          AEFVEVTK_precursor_Soroush_SDC_W1730_high
# 15    AEFVEVTK_precursor [M+1]_Soroush_SDC_W1730_high
# 16    AEFVEVTK_precursor [M+2]_Soroush_SDC_W1730_high
# 17                 AEFVEVTK_y6_Soroush_SDC_W1730_high
# 18                  AEFVEVTK_b2_Soroush_SDC_W1730_low
# 19                  AEFVEVTK_y2_Soroush_SDC_W1730_low
# Name: plot_cat, dtype: object

# %%
df_area_ratio_conc['plot_cat'].nunique()
# Out:
# 194

# %% [markdown]
# ## Get Linear Fit parameters

# %%
from sklearn import linear_model, metrics
import matplotlib.pyplot as plt

def get_plot(data:pd.DataFrame, plot_cat:str, ax):

    cat_data = data[data['plot_cat'] == plot_cat].copy()
    # print(cat_data)

    # fig, ax = plt.subplots()
    cat_data.dropna(axis=0, inplace=True)

    y = cat_data['area_ratio'].values
    x = cat_data['heavy_conc'].values

    ax.scatter(x, y)

    x = x[:, np.newaxis]
    y = y[:, np.newaxis]

    model = linear_model.LinearRegression()

    model.fit(x, y)

    y_fit = model.predict(x)

    ax.plot(x.flatten(), y_fit.flatten())
    ax.set_title(plot_cat)
    
    return ax

def get_linear_fit(data:pd.DataFrame, plot_cat:str):

    cat_data = data[data['plot_cat'] == plot_cat].copy()
    # print(cat_data)

    # fig, ax = plt.subplots()
    cat_data.dropna(axis=0, inplace=True)

    y = cat_data['area_ratio'].values
    x = cat_data['heavy_conc'].values

    # ax.scatter(x, y)

    x = x[:, np.newaxis]
    y = y[:, np.newaxis]

    model = linear_model.LinearRegression()

    model.fit(x, y)

    y_fit = model.predict(x)

    # ax.plot(x.flatten(), y_fit.flatten())

    r2 = metrics.r2_score(y, y_fit)
    intercept = model.intercept_.squeeze()
    grad = model.coef_[0].squeeze()


    # print(f"R^2: {r2}")
    # print(f"intercept: {intercept}")
    # print(f"gradient:{grad}")

    # plt.show()
    
    return (r2, intercept, grad)

plot_cats = df_area_ratio_conc['plot_cat'].unique()

# plot_df = df_area_ratio_conc[df_area_ratio_conc.peptide=='GGLEPINFQTAADQAR'] # get only one peptide
# plot_df = plot_df[[peptide_dilution_name_col, 'area_ratio', 'heavy_conc', 'plot_cat']]
plot_df = df_area_ratio_conc


cats = []
r2s = []
intercepts = []
grads = []

for cat in plot_cats:
    # print(cat)
    r2, intercept, grad = get_linear_fit(plot_df, cat)
    cats.append(cat)
    r2s.append(r2)
    intercepts.append(intercept)
    grads.append(grad)

# n_plot_cats = len(plot_cats)
# fig_ax_dims = (4,4)
# n_figs = np.ceil(n_plot_cats / np.product(fig_ax_dims))

# axs = []
# for fig_i in n_figs:
#     fig, axs = plt.subplots(nrows=fig_ax_dims[0], ncols=fig_ax_dims[1])
#     fig_axs = axs.flatten()
#     for ax in fig_axs:
#         axs.append(ax)


# result_data_folder = pathlib.Path("../../reports/ms_work/plots")
# for cat in plot_cats:
#     fig, ax = plt.subplots()
#     ax = get_plot(plot_df, cat, ax)
#     fig = plt.gcf()
#     fig.savefig(fname=result_data_folder.joinpath(cat))



df_plot_cat_fit_params = pd.DataFrame({'plot_cat':cats,
              'R2':r2s,
              'intercept':intercepts,
              'gradient':grads})
# Out:
# c:\Users\Aroge\anaconda3\envs\genomic\lib\site-packages\sklearn\metrics\_regression.py:682: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\Aroge\anaconda3\envs\genomic\lib\site-packages\sklearn\metrics\_regression.py:682: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %% [markdown]
# ## Plots

# %% [markdown]
# ### plot by plot cat

# %%
result_data_folder = pathlib.Path("../../reports/ms_work/plots")
for cat in plot_cats:
    fig, ax = plt.subplots()
    ax = get_plot(plot_df, cat, ax)
    fig = plt.gcf()
    fig.savefig(fname=result_data_folder.joinpath(cat))
# Out:
# c:\Users\Aroge\anaconda3\envs\genomic\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Plots (by group)

# %%
result_data_folder = pathlib.Path("../../reports/ms_work/plots_by_grp")

def get_grp_plot(data:pd.DataFrame, plot_grp_cat:str, ax):

    cat_data = data[data['plot_cat_grp'] == plot_grp_cat].copy()
    # print(cat_data)

    # fig, ax = plt.subplots()
    cat_data.dropna(axis=0, inplace=True)

    y = cat_data['area_ratio'].values
    x = cat_data['heavy_conc'].values

    ax.scatter(x, y)

    x = x[:, np.newaxis]
    y = y[:, np.newaxis]

    model = linear_model.LinearRegression()

    model.fit(x, y)

    y_fit = model.predict(x)

    ax.plot(x.flatten(), y_fit.flatten())
    ax.set_title(plot_grp_cat)
    
    return ax

def get_plot_grp_col(plot_cat:str):

    items = plot_cat.split("_")

    del items[1]
    grp_str = "_".join(items)

    return grp_str

    


plot_df['plot_cat_grp'] = plot_df['plot_cat'].apply(get_plot_grp_col)
plot_cat_grps = plot_df['plot_cat_grp'].unique()


for grp in plot_cat_grps:
    fig, ax = plt.subplots()
    ax = get_grp_plot(data=plot_df, plot_grp_cat=grp, ax=ax)
    fig = plt.gcf()
    fig.savefig(fname=result_data_folder.joinpath(grp))

# %%
len(plot_cat_grps)
# Out:
# 26

# %%
# merge to assign group properties to individual rows
df_area_ratio_conc_n_fit_params = pd.merge(df_area_ratio_conc,
                                           right=df_plot_cat_fit_params,
                                           on='plot_cat',
                                           how='left')

df_area_ratio_conc_n_fit_params
# save to csv file
# df_area_ratio_conc_n_fit_params.to_csv('area_ratio_conc_n_fit_params.csv', index=False)
# Out:
#            peptide               protein  \
# 0         AEFVEVTK  sp|P02769|ALBU_BOVIN
# 1         AEFVEVTK  sp|P02769|ALBU_BOVIN
# 2         AEFVEVTK  sp|P02769|ALBU_BOVIN
# 3         AEFVEVTK  sp|P02769|ALBU_BOVIN
# 4         AEFVEVTK  sp|P02769|ALBU_BOVIN
# ...            ...                   ...
# 1073  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1074  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1075  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1076  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1077  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
#
#                                      replicate  product charge  \
# 0     Soroush_SDC_W1730_Sup_D0_column12_2uL_20               1
# 1     Soroush_SDC_W1730_Sup_D0_column12_2uL_20               1
# 2     Soroush_SDC_W1730_Sup_D0_column12_2uL_20               1
# 3     Soroush_SDC_W1730_Sup_D0_column12_2uL_20               1
# 4     Soroush_SDC_W1730_Sup_D0_column12_2uL_20               1
# ...                                        ...             ...
# 1073     Soroush_SDC_WW_Sup_D4_column12_2uL_89               1
# 1074     Soroush_SDC_WW_Sup_D4_column12_2uL_89               2
# 1075     Soroush_SDC_WW_Sup_D4_column12_2uL_89               2
# 1076     Soroush_SDC_WW_Sup_D4_column12_2uL_89               2
# 1077     Soroush_SDC_WW_Sup_D4_column12_2uL_89               2
#
#          fragment ion  area_ratio      area_min     area_max  \
# 0                  b2    0.000344  3.157382e+09    1085662.0
# 1                  y2    0.000128  4.009150e+08      51280.0
# 2                  y4    0.000017  6.640748e+08      11599.0
# 3                  y5    0.000003  8.254646e+08       2376.0
# 4                  y6    0.000171  2.778528e+09     475204.0
# ...               ...         ...           ...          ...
# 1073               y9    0.708577  2.510951e+07   17792034.0
# 1074        precursor    0.729514  6.567330e+08  479095968.0
# 1075  precursor [M+1]    0.689912  4.416241e+08  304681568.0
# 1076  precursor [M+2]    0.637243  1.895787e+08  120807784.0
# 1077              y10    0.697303  5.115121e+07   35667880.0
#
#      peptide_dilution_name      Peptides dilution  heavy_conc  \
# 0              AEFVEVTK_D0      AEFVEVTK       D0    0.000000
# 1              AEFVEVTK_D0      AEFVEVTK       D0    0.000000
# 2              AEFVEVTK_D0      AEFVEVTK       D0    0.000000
# 3              AEFVEVTK_D0      AEFVEVTK       D0    0.000000
# 4              AEFVEVTK_D0      AEFVEVTK       D0    0.000000
# ...                    ...           ...      ...         ...
# 1073       YICDNQDTISSK_D4  YICDNQDTISSK       D4    0.007858
# 1074       YICDNQDTISSK_D4  YICDNQDTISSK       D4    0.007858
# 1075       YICDNQDTISSK_D4  YICDNQDTISSK       D4    0.007858
# 1076       YICDNQDTISSK_D4  YICDNQDTISSK       D4    0.007858
# 1077       YICDNQDTISSK_D4  YICDNQDTISSK       D4    0.007858
#
#                                               plot_cat        R2  \
# 0                    AEFVEVTK_b2_Soroush_SDC_W1730_low  0.989631
# 1                    AEFVEVTK_y2_Soroush_SDC_W1730_low  0.988234
# 2                    AEFVEVTK_y4_Soroush_SDC_W1730_low  0.988140
# 3                    AEFVEVTK_y5_Soroush_SDC_W1730_low  0.988700
# 4                    AEFVEVTK_y6_Soroush_SDC_W1730_low  0.988829
# ...                                                ...       ...
# 1073               YICDNQDTISSK_y9_Soroush_SDC_WW_high  0.998827
# 1074        YICDNQDTISSK_precursor_Soroush_SDC_WW_high  0.954948
# 1075  YICDNQDTISSK_precursor [M+1]_Soroush_SDC_WW_high  0.974994
# 1076  YICDNQDTISSK_precursor [M+2]_Soroush_SDC_WW_high  0.956988
# 1077              YICDNQDTISSK_y10_Soroush_SDC_WW_high  0.998716
#
#                  intercept            gradient
# 0     -0.13147736467139093   11.51259813335332
# 1      -0.1502222186570894  12.334220374266625
# 2     -0.14864927352590418   12.30423952857855
# 3      -0.1387292636187265  11.684069531545752
# 4     -0.14055022618436963  12.197474762376542
# ...                    ...                 ...
# 1073   -3.8072873413344297  229.38052894238007
# 1074   -16.824865355130406  240.57479242298194
# 1075    -14.58724185388455   257.2554796725508
# 1076   -18.248494717278717  261.75467289705176
# 1077     -3.68832333117507   228.5492469346212
#
# [1078 rows x 16 columns]

# %%
q90 = [0.941, 0.765, 0.642, 0.56, 0.507, 0.468, 0.437,
       0.412, 0.392, 0.376, 0.361, 0.349, 0.338, 0.329,
       0.32, 0.313, 0.306, 0.3, 0.295, 0.29, 0.285, 0.281,
       0.277, 0.273, 0.269, 0.266, 0.263, 0.26
      ]

q95 = [0.97, 0.829, 0.71, 0.625, 0.568, 0.526, 0.493, 0.466,
       0.444, 0.426, 0.41, 0.396, 0.384, 0.374, 0.365, 0.356,
       0.349, 0.342, 0.337, 0.331, 0.326, 0.321, 0.317, 0.312,
       0.308, 0.305, 0.301, 0.29
      ]

q99 = [0.994, 0.926, 0.821, 0.74, 0.68, 0.634, 0.598, 0.568,
       0.542, 0.522, 0.503, 0.488, 0.475, 0.463, 0.452, 0.442,
       0.433, 0.425, 0.418, 0.411, 0.404, 0.399, 0.393, 0.388,
       0.384, 0.38, 0.376, 0.372
       ]

Q90 = {n:q for n,q in zip(range(3,len(q90)+1), q90)}
Q95 = {n:q for n,q in zip(range(3,len(q95)+1), q95)}
Q99 = {n:q for n,q in zip(range(3,len(q99)+1), q99)}

def dixon_test(data, left=True, right=True, q_dict=Q95):
    """
    Keyword arguments:
        data = A ordered or unordered list of data points (int or float).
        left = Q-test of minimum value in the ordered list if True.
        right = Q-test of maximum value in the ordered list if True.
        q_dict = A dictionary of Q-values for a given confidence level,
            where the dict. keys are sample sizes N, and the associated values
            are the corresponding critical Q values. E.g.,
            {3: 0.97, 4: 0.829, 5: 0.71, 6: 0.625, ...}

    Returns a list of 2 values for the outliers, or None.
    E.g.,
       for [1,1,1] -> [None, None]
       for [5,1,1] -> [None, 5]
       for [5,1,5] -> [1, None]

    """
    assert(left or right), 'At least one of the variables, `left` or `right`, must be True.'
    assert(len(data) >= 3), 'At least 3 data points are required'
    assert(len(data) <= max(q_dict.keys())), 'Sample size too large'

    sdata = sorted(data)
    Q_mindiff, Q_maxdiff = (0,0), (0,0)

    if left:
        Q_min = (sdata[1] - sdata[0])
        try:
            Q_min /= (sdata[-1] - sdata[0])
        except ZeroDivisionError:
            pass
        Q_mindiff = (Q_min - q_dict[len(data)], sdata[0])

    if right:
        Q_max = abs((sdata[-2] - sdata[-1]))
        try:
            Q_max /= abs((sdata[0] - sdata[-1]))
        except ZeroDivisionError:
            pass
        Q_maxdiff = (Q_max - q_dict[len(data)], sdata[-1])

    if not Q_mindiff[0] > 0 and not Q_maxdiff[0] > 0:
        outliers = [None, None]

    elif Q_mindiff[0] == Q_maxdiff[0]:
        outliers = [Q_mindiff[1], Q_maxdiff[1]]

    elif Q_mindiff[0] > Q_maxdiff[0]:
        outliers = [Q_mindiff[1], None]

    else:
        outliers = [None, Q_maxdiff[1]]

    return outliers


dixon_test([0.142, 0.153, 0.135, 0.002, 0.175], left=False)

# %% [markdown]
# # Fit metric

# %%
def get_fit_param_cat(row):
    """Get the fit param category (C18_SDS, C18_SDC, etc..)."""

    replicate = row['replicate']
    peptide = row['peptide']

    rep_elements = replicate.split('_')[0:3]

    cat_name = [peptide]  + rep_elements
    cat_name = '_'.join(cat_name)
    return cat_name

def qtest(data, right=True):

    sorted_data = sorted(data)

    if right:
        gap = sorted_data[-1] - sorted_data[-2]

    else:
        gap = sorted_data[1] - sorted_data[0]

    try:
        range = sorted_data[-1] - sorted_data[0]
        q_val = gap / range
    except ZeroDivisionError:
        q_val = gap

    return q_val

def get_grp_fit_agg(grouped_df:pd.DataFrame):
    """Get the aggregate values for each group."""

    df = grouped_df[['intercept', 'gradient', 'R2']].copy()
    gradient = df['gradient'].values
    intercept = df['intercept'].values
    r2 = df['R2'].values

    mean_grad = gradient.mean()
    stdv_grad = gradient.std()
    cov_grad = stdv_grad / mean_grad
    qtest_grad_right = qtest(gradient, right=True)

    mean_intercept = intercept.mean()
    stdv_intercept = intercept.std()
    cov_intercept = stdv_intercept / mean_intercept
    qtest_intercept_right = qtest(intercept, right=True)

    mean_r2 = r2.mean()
    stdv_r2 = r2.std()
    cov_r2 = stdv_r2 / mean_r2
    qtest_r2_right = qtest(r2, right=True)

    cols_dict = {'mean_grad':mean_grad, 'stdv_grad':stdv_grad,
                 'cov_grad':cov_grad, 'qtest_grad':qtest_grad_right, 
                 'mean_intercept':mean_intercept, 'stdv_intercept':stdv_intercept,
                 'cov_intercept':cov_intercept, 'qtest_intercept':qtest_intercept_right,
                 'mean_r2':mean_r2, 'stdv_r2':stdv_r2,
                 'cov_r2':cov_r2, 'qtest_r2':qtest_r2_right
                 }

    return pd.Series(cols_dict)


# create plot categories
temp = df_area_ratio_conc_n_fit_params.copy()
temp['fit_param_grp'] = temp.apply(get_fit_param_cat, axis=1)

cols_to_group_by = ['fit_param_grp']
df_fit_param_agg = temp.groupby(cols_to_group_by).apply(get_grp_fit_agg).reset_index()

df_w_fit_param_agg = pd.merge(left=temp, right=df_fit_param_agg, how='left', on=cols_to_group_by)
df_w_fit_param_agg.head(3)
# Out:
#     peptide               protein                                 replicate  \
# 0  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 1  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
# 2  AEFVEVTK  sp|P02769|ALBU_BOVIN  Soroush_SDC_W1730_Sup_D0_column12_2uL_20
#
#    product charge fragment ion  area_ratio      area_min   area_max  \
# 0               1           b2    0.000344  3.157382e+09  1085662.0
# 1               1           y2    0.000128  4.009150e+08    51280.0
# 2               1           y4    0.000017  6.640748e+08    11599.0
#
#   peptide_dilution_name  Peptides  ...  cov_grad  qtest_grad mean_intercept  \
# 0           AEFVEVTK_D0  AEFVEVTK  ...  0.056969         0.0      -0.164569
# 1           AEFVEVTK_D0  AEFVEVTK  ...  0.056969         0.0      -0.164569
# 2           AEFVEVTK_D0  AEFVEVTK  ...  0.056969         0.0      -0.164569
#
#    stdv_intercept cov_intercept qtest_intercept   mean_r2   stdv_r2    cov_r2  \
# 0        0.023073     -0.140203             0.0  0.986283  0.002647  0.002684
# 1        0.023073     -0.140203             0.0  0.986283  0.002647  0.002684
# 2        0.023073     -0.140203             0.0  0.986283  0.002647  0.002684
#
#    qtest_r2
# 0       0.0
# 1       0.0
# 2       0.0
#
# [3 rows x 29 columns]

# %%
# The columns that have zero area as denominator
df_w_fit_param_agg[df_w_fit_param_agg.area_ratio.isna()]
# Out:
#            peptide               protein  \
# 855   YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 856   YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 857   YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 858   YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 862   YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1025  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1027  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1028  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1029  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1033  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1043  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1044  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1045  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1046  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
# 1050  YICDNQDTISSK  sp|P02769|ALBU_BOVIN
#
#                                    replicate  product charge fragment ion  \
# 855   Soroush_SDC_W42_Sup_D2_column12_2uL_99               1           b2
# 856   Soroush_SDC_W42_Sup_D2_column12_2uL_99               1          y10
# 857   Soroush_SDC_W42_Sup_D2_column12_2uL_99               1           y3
# 858   Soroush_SDC_W42_Sup_D2_column12_2uL_99               1           y9
# 862   Soroush_SDC_W42_Sup_D2_column12_2uL_99               2          y10
# 1025  Soroush_SDC_WW_Sup_D2_column12_2uL_101               1           b2
# 1027  Soroush_SDC_WW_Sup_D2_column12_2uL_101               1          y10
# 1028  Soroush_SDC_WW_Sup_D2_column12_2uL_101               1           y3
# 1029  Soroush_SDC_WW_Sup_D2_column12_2uL_101               1           y9
# 1033  Soroush_SDC_WW_Sup_D2_column12_2uL_101               2          y10
# 1043   Soroush_SDC_WW_Sup_D3_column12_2uL_29               1           b2
# 1044   Soroush_SDC_WW_Sup_D3_column12_2uL_29               1          y10
# 1045   Soroush_SDC_WW_Sup_D3_column12_2uL_29               1           y3
# 1046   Soroush_SDC_WW_Sup_D3_column12_2uL_29               1           y9
# 1050   Soroush_SDC_WW_Sup_D3_column12_2uL_29               2          y10
#
#       area_ratio  area_min  area_max peptide_dilution_name      Peptides  ...  \
# 855          NaN       0.0  104808.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 856          NaN       0.0  233180.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 857          NaN       0.0  100127.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 858          NaN       0.0   42985.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 862          NaN       0.0  149244.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 1025         NaN       0.0  212854.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 1027         NaN       0.0  556007.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 1028         NaN       0.0  207790.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 1029         NaN       0.0  127013.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 1033         NaN       0.0  294669.0       YICDNQDTISSK_D2  YICDNQDTISSK  ...
# 1043         NaN       0.0   24997.0       YICDNQDTISSK_D3  YICDNQDTISSK  ...
# 1044         NaN       0.0  110217.0       YICDNQDTISSK_D3  YICDNQDTISSK  ...
# 1045         NaN       0.0   18228.0       YICDNQDTISSK_D3  YICDNQDTISSK  ...
# 1046         NaN       0.0    8869.0       YICDNQDTISSK_D3  YICDNQDTISSK  ...
# 1050         NaN       0.0  110325.0       YICDNQDTISSK_D3  YICDNQDTISSK  ...
#
#      cov_grad  qtest_grad mean_intercept  stdv_intercept cov_intercept  \
# 855   0.25654         0.0      -4.668425       11.889303     -2.546748
# 856   0.25654         0.0      -4.668425       11.889303     -2.546748
# 857   0.25654         0.0      -4.668425       11.889303     -2.546748
# 858   0.25654         0.0      -4.668425       11.889303     -2.546748
# 862   0.25654         0.0      -4.668425       11.889303     -2.546748
# 1025  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1027  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1028  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1029  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1033  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1043  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1044  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1045  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1046  0.12880         0.0      -7.672875        5.300528     -0.690814
# 1050  0.12880         0.0      -7.672875        5.300528     -0.690814
#
#      qtest_intercept mean_r2  stdv_r2  cov_r2  qtest_r2
# 855         0.529508     NaN      NaN     NaN       0.0
# 856         0.529508     NaN      NaN     NaN       0.0
# 857         0.529508     NaN      NaN     NaN       0.0
# 858         0.529508     NaN      NaN     NaN       0.0
# 862         0.529508     NaN      NaN     NaN       0.0
# 1025        0.394030     NaN      NaN     NaN       0.0
# 1027        0.394030     NaN      NaN     NaN       0.0
# 1028        0.394030     NaN      NaN     NaN       0.0
# 1029        0.394030     NaN      NaN     NaN       0.0
# 1033        0.394030     NaN      NaN     NaN       0.0
# 1043        0.394030     NaN      NaN     NaN       0.0
# 1044        0.394030     NaN      NaN     NaN       0.0
# 1045        0.394030     NaN      NaN     NaN       0.0
# 1046        0.394030     NaN      NaN     NaN       0.0
# 1050        0.394030     NaN      NaN     NaN       0.0
#
# [15 rows x 29 columns]

# %%
result_data_folder = pathlib.Path("../../reports/ms_work")

df_w_fit_param_agg.to_csv(result_data_folder.joinpath('data_with_fit_param_aggregate_soroush_2.csv'), index=False)
